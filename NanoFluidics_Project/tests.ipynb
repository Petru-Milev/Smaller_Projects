# %%
import numpy as np
import os

# %%
t = 1e-9
dt = 1e-15
D = 2*1e-9

print(np.sqrt(2*D*t)*4)
# Out:
# 8e-09

# %%
a = sigma(1, 2)
type(a)
# Out:
# int

# %%
a = np.array([1, 2, 3])
b = np.linalg.norm(a)
c = np.sqrt(np.sum(a**2))
print(b, c)
# Out:
# 3.7416573867739413 3.7416573867739413

# %%
a = None

if a:
    print("a is not None")

a = 10 
if a:
    print("a is not None")
# Out:
# a is not None

# %%
def solve_langevin(x, z, E, gamma, D, dt, e = 1.0):
    x_new = x + e*z*E*dt/gamma + np.sqrt(2*D*dt)#*np.random.normal(0,1)
    return x_new

# %%
x = 0 
a = solve_langevin(x, 0, 1, 1, 1, 1)
a
# Out:
# 1.4142135623730951

# %%
a = 1.60217663e-19
print(10000000000000*a)
# Out:
# 1.6021766299999998e-06

# %%
current_directoru = os.getcwd()
print(current_directoru)
# Out:
# /Users/petrumilev/Documents/projects_python/Smaller_Projects/NanoFluidics_Project

# %%
100000000000000000%100000000
# Out:
# 0

# %%
200//10
# Out:
# 20

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.patches as patches
from matplotlib.patches import Circle, PathPatch
import mpl_toolkits.mplot3d.art3d as art3d

# %%
x_array = np.array([-10, -9, -8, 1, 2, 3, 4, 5, 6, 7, 8, 9])
y_array = np.array([-10, -9, -8, 1, 2, 3, 4, 5, 6, 7, 8, 9])
z_array = np.array([-10, -9, -8, 1, 2, 3, 4, 5, 6, 7, 8, 9])
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(x_array, y_array, z_array, c = 'r', marker = 'o', markersize = 1)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
p = Circle((0, 0), 5, color='b', alpha=0.2)
#p1 = Circle((0, 0), object.pore_radius - 2*object.particle_radius, color='r', alpha=0.2)
ax.add_patch(p)
#ax.add_patch(p1)
art3d.pathpatch_2d_to_3d(p, z=0, zdir="z")
#art3d.pathpatch_2d_to_3d(p1, z=0, zdir="z")

plt.show()

# %%
'''
========================
3D surface (solid color)
========================

Demonstrates a very basic plot of a 3D surface using a solid color.
'''

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Make data
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
x = 10 * np.outer(np.cos(u), np.sin(v))
y = 10 * np.outer(np.sin(u), np.sin(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))

# Plot the surface

ax.plot_wireframe(x, y, z, color='b')

plt.show()
